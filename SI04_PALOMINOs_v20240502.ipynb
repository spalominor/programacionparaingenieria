# %% [markdown]
# <a href="https://colab.research.google.com/github/spalominor/programacionparaingenieria/blob/main/SI04_PALOMINOs_v20240502.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## «*La escuela es la agencia publicitaria que te hace creer que necesitas la sociedad tal como es*».
#
# ### [Iván ILLICH](https://es.wikipedia.org/wiki/Iv%C3%A1n_Illich)

# %% [markdown]
# #SI04 Matplotlib
#
# Actividad individual.
#
# Utilice el dataset asignado en [datasets panda](https://docs.google.com/spreadsheets/d/e/2PACX-1vQi3ziCNg_TlAHPvHceFDyqFZeouQk7-uWcSSv-VTsYHnzx5VEyp3u_rp5pNiuPdNta898xj7vJzZPL/pubhtml).
#
# Resuelva los siguientes ejercicios con códigos que se ajusten al PEP8. Recuerde incluir los comentarios en el código y documentar las funciones con docstrings al estilo de Google.
#
# **Importante:**
#
# **no se permite la utilización de ciclos (for or while) para resolver los ejercicios.**
#
# **todos los ejercicios deben ser resueltos con Matplotlib, puede utilizar NumPy y Pandas para la preparación de los datos.**

# %% [markdown]
# # Preparación del ejercicio
#
# *   Importe las librerías requeridas
# *   Lea el dataset a utilizar, **UNA SOLA VEZ**, desde una url y utilice esa información para resolver los ejercicios indicados
#
# **Sugerencia**: suba el dataset a un repositorio de GitHub, o al Googledrive de su **cuenta personal de gmail** y luego publíquelo en la web como un archivo *.csv.
#
# Nota: si lo desea puede utilizar otro método para obtener la url del dataset.

# %%
# Escriba aquí su código

# Importar las librerías requeridas
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt



# Conocer la versiones de las librerías instaladas
print("Versión de NumPy: ", np.__version__)
print("Versión de Pandas: ", pd.__version__)

# Se necesita importar matplotlib en todo su conjunto para ver la versión
#print("Versión de MatPlotLib: ", matplotlib.__version__)
# >>> Versión de MatPlotLib:  3.7.1

# Guardar en la variable 'ruta' la url del dataset
ruta = (
    "https://docs.google.com/spreadsheets/d/e/2PACX-1vRQ8x5bRX8x6"
    "CB54kpTT7BSss8ImdQf-1VhKZfRf79GgAyA_LWCot6EBjKi8qvL_S1ah6V8I"
    "haalpi_/pub?gid=655073616&single=true&output=csv"
)

# Cargar el dataset a partir de la ruta establecida
df_pokemon = pd.read_csv(ruta)

# Verificar la lectura del dataset
print(df_pokemon.info())
# Out:
# Versión de NumPy:  1.25.2
# Versión de Pandas:  2.0.3
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 801 entries, 0 to 800
# Data columns (total 41 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   abilities          801 non-null    object
#  1   against_bug        801 non-null    float64
#  2   against_dark       801 non-null    float64
#  3   against_dragon     801 non-null    float64
#  4   against_electric   801 non-null    float64
#  5   against_fairy      801 non-null    float64
#  6   against_fight      801 non-null    float64
#  7   against_fire       801 non-null    float64
#  8   against_flying     801 non-null    float64
#  9   against_ghost      801 non-null    float64
#  10  against_grass      801 non-null    float64
#  11  against_ground     801 non-null    float64
#  12  against_ice        801 non-null    float64
#  13  against_normal     801 non-null    float64
# ...

# %% [markdown]
# ## Ejercicio 00
#
# Seleccione dos columnas numéricas del dataset y haga un gráfico tipo **plot**. Coloque título al gráfico y etiquete los dos ejes.

# %%
# Escriba su código aquí

# Seleccionar dos columnas numéricas del DataFrame
columna1 = 'attack'
columna2 = 'hp'

# Ordenar el DataFrame por la primera columna seleccionada
df_pokemon_sorted = df_pokemon.sort_values(by=columna1)

# Crear el gráfico de líneas
plt.figure(figsize=(8, 6))
plt.plot(df_pokemon_sorted[columna1], df_pokemon_sorted[columna2])

# Título y etiquetas de los ejes
plt.title('Comparación entre Ataque y HP de los Pokémon')
plt.xlabel('Ataque')
plt.ylabel('Puntos de vida (HP)')

# Activar la cuadrícula
plt.grid(True)

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ## Ejercicio 01
#
# Seleccione cinco columnas numéricas del dataset y haga un gráfico tipo **scatter**. Coloque título al gráfico y etiquete los dos ejes.

# %%
# Escriba su código aquí

# Seleccionar cinco columnas numéricas del DataFrame
columnas = ['hp', 'attack', 'defense', 'speed', 'sp_attack']

# Crear el gráfico de dispersión
plt.figure(figsize=(8, 6))

# Dibujar los puntos de dispersión de cada columna
plt.scatter(df_pokemon[columnas[0]],
            df_pokemon[columnas[1]], label='Attack')
plt.scatter(df_pokemon[columnas[0]],
            df_pokemon[columnas[2]], label='Defense')
plt.scatter(df_pokemon[columnas[0]],
            df_pokemon[columnas[3]], label='Speed')
plt.scatter(df_pokemon[columnas[0]],
            df_pokemon[columnas[4]], label='Super Attack')

# Título y etiquetas de los ejes
plt.title('Comparación de HP versus Estadísticas de Pokémon')
plt.xlabel('Puntos de vida (HP)')
plt.ylabel('Valor')

# Agregar leyenda y cuadrícula
plt.legend()
plt.grid(True)

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ## Ejercicio 02
#
# Seleccione cuatro columnas numéricas del dataset y haga un gráfico tipo **stackplot** (apilable). Coloque título al gráfico, etiquete los dos ejes e incluya una leyenda dentro del gráfico.

# %%
# Escriba su código aquí

# Ordenar el DataFrame por la columna 'hp'
df_pokemon_sorted = df_pokemon.sort_values(by='hp')

# Seleccionar las columnas numéricas del DataFrame
columna_attack = df_pokemon_sorted['attack'].values
columna_defense = df_pokemon_sorted['defense'].values
columna_speed = df_pokemon_sorted['speed'].values

# Crear el gráfico de tipo stackplot
plt.figure(figsize=(12, 8))
plt.stackplot(df_pokemon_sorted['hp'],
              columna_attack,
              columna_defense,
              columna_speed,
              labels=['Attack', 'Defense', 'Speed'])

# Título y etiquetas de los ejes
plt.title('Composición de Estadísticas de Pokémon')
plt.xlabel('HP del Pokémon')
plt.ylabel('Valor')

# Agregar leyenda dentro del gráfico en la parte superior derecha
plt.legend(loc='upper right')

# Activar la cuadrícula
plt.grid(True)

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ## Ejercicio 03
#
# Cree una figura que incluya los gráficos construidos en los puntos anteriores en un mismo espacio.

# %%
# Escriba su código aquí

# Crear la figura y los subgráficos
fig = plt.figure(figsize=(16, 6))

# Definir gráfico 1 ---------------------------------------------
# Columna para el eje x
columna1_fig1 = 'attack'

# Columna para el eje y
columna2_fig1 = 'hp'

# Ordenar el DataFrame por la columna de ataque
df_pokemon_sorted_fig1 = df_pokemon.sort_values(by=columna1_fig1)

# Dibujar el gráfico de líneas
ax1 = fig.add_subplot(131)
ax1.plot(df_pokemon_sorted_fig1[columna1_fig1],
         df_pokemon_sorted_fig1[columna2_fig1])

# Establecer el título del gráfico
ax1.set_title('Comparación entre Ataque y HP de Pokémon')

# Etiquetar el eje x
ax1.set_xlabel('Ataque')

# Etiquetar el eje y
ax1.set_ylabel('Puntos de vida (HP)')

# Mostrar la cuadrícula en el gráfico
ax1.grid(True)

# Definir gráfico 2 ---------------------------------------------
# Columnas para los puntos de dispersión
columnas_fig2 = ['hp', 'attack', 'defense', 'speed', 'sp_attack']

# Dibujar puntos de dispersión para cada estadística seleccionada
# Dibujar los puntos según el ataque
ax2 = fig.add_subplot(133)
ax2.scatter(df_pokemon[columnas_fig2[0]],
            df_pokemon[columnas_fig2[1]],
            label='Attack')

# Dibujar los puntos según la defensa
ax2.scatter(df_pokemon[columnas_fig2[0]],
            df_pokemon[columnas_fig2[2]],
            label='Defense')

# Dibujar los puntos según la velocidad
ax2.scatter(df_pokemon[columnas_fig2[0]],
            df_pokemon[columnas_fig2[3]],
            label='Speed')

# Dibujar los puntos según el super ataque
ax2.scatter(df_pokemon[columnas_fig2[0]],
            df_pokemon[columnas_fig2[4]],
            label='Super Attack')

# Establecer el título del gráfico
ax2.set_title('Comparación de HP versus Estadísticas de Pokémon')

# Etiquetar el eje x
ax2.set_xlabel('Puntos de vida (HP)')

# Etiquetar el eje y
ax2.set_ylabel('Valor')

# Mostrar la leyenda
ax2.legend()

# Mostrar la cuadrícula en el gráfico
ax2.grid(True)

# Definir gráfico 3 ---------------------------------------------
# Ordenar el DataFrame por HP
df_pokemon_sorted_fig3 = df_pokemon.sort_values(by='hp')

# Obtener los valores del ataque
columna_attack = df_pokemon_sorted_fig3['attack'].values

# Obtener los valores de la defensa
columna_defense = df_pokemon_sorted_fig3['defense'].values

# Obtener los valores de la velocidad
columna_speed = df_pokemon_sorted_fig3['speed'].values

# Dibujar un gráfico de área apilada
ax3 = fig.add_subplot(132)
ax3.stackplot(df_pokemon_sorted_fig3['hp'],
              columna_attack,
              columna_defense,
              columna_speed,
              labels=['Attack', 'Defense', 'Speed'])

# Establecer el título del gráfico
ax3.set_title('Composición de Estadísticas de Pokémon')

# Etiquetar el eje x
ax3.set_xlabel('HP del Pokémon')

# Etiquetar el eje y
ax3.set_ylabel('Valor')

# Mostrar la leyenda en la esquina superior izquierda
ax3.legend(loc='upper left')

# Mostrar la cuadrícula en el gráfico
ax3.grid(True)

# Ajustar espaciado entre subgráficos
fig.tight_layout()

# Mostrar la figura
plt.show()

# %% [markdown]
# ## Ejercicio 04
#
# Seleccione las columnas que considere pertinentes del dataset y haga un gráfico de barras horizontales. Coloque título al gráfico y etiquete los dos ejes.

# %%
# Escriba su código aquí

# Seleccionar las columnas pertinentes del DataFrame
columnas_pertinentes = ['base_happiness',
                        'base_egg_steps',
                        'base_total']

# Agrupar los datos por generación y calcular el promedio de cada columna
promedios_generacion = df_pokemon.groupby('generation')[
    columnas_pertinentes].mean()

# Crear el gráfico de barras horizontales apiladas
plt.figure(figsize=(10, 6))

# Definir los colores para las barras
colores = ['orange', 'purple', 'green']

# Crear la primera barra
barra_base_happiness = plt.barh(promedios_generacion.index,
                                promedios_generacion['base_happiness'],
                                color=colores[0],
                                label='Base happiness')

# Crear la segunda barra empezando donde termina la primera
barra_base_egg_steps = plt.barh(promedios_generacion.index,
                                promedios_generacion['base_egg_steps'],
                                color=colores[1],
                                label='Base egg steps',
                                left=promedios_generacion['base_happiness'])

# Calcular las posiciones para la tercera barra
posiciones_base_total = promedios_generacion[
    'base_happiness'] + promedios_generacion['base_egg_steps']

# Crear la tercera barra empezando donde termina la segunda
barra_base_total = plt.barh(promedios_generacion.index,
                            promedios_generacion['base_total'],
                            color=colores[2],
                            label='Base total',
                            left=posiciones_base_total)

# Título y etiquetas de los ejes
plt.title('Promedio de las estadísticas base de los Pokémon por Generación')
plt.xlabel('Valor promedio')
plt.ylabel('Generación')

# Agregar leyenda y la cuadrícula
plt.legend()
plt.grid(True)

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ## Ejercicio 05
#
# Seleccione las columnas que considere pertinentes del dataset y haga un gráfico de barras verticales. Coloque título al gráfico y etiquete los dos ejes.

# %%
import matplotlib.pyplot as plt

# Agrupar los datos por generación y calcular el promedio de 'hp' y 'attack'
promedio_por_generacion = df_pokemon.groupby('generation')[['hp',
                                                            'attack']].mean()

# Obtener los índices de las generaciones (1, 2, ..., 7)
generaciones = promedio_por_generacion.index

# Obtener los promedios de puntos de vida y ataque
promedio_hp = promedio_por_generacion['hp']
promedio_attack = promedio_por_generacion['attack']

# Crear el gráfico de barras verticales
plt.figure(figsize=(10, 6))

# Dibujar la barra según los puntos de vida
plt.bar(generaciones,
        promedio_hp,
        color='green',
        label='Puntos de Vida (HP)')

# Dibujar la barra según el ataque encima de la barra de puntos de vida
plt.bar(generaciones,
        promedio_attack,
        color='skyblue',
        label='Ataque',
        bottom=promedio_hp)

# Título y etiquetas de los ejes
plt.title('Promedio de Puntos de Vida y Ataque por Generación')
plt.xlabel('Generación')
plt.ylabel('Promedio')

# Establecer las etiquetas del eje x como las generaciones
plt.xticks(generaciones)

# Agregar leyenda y cuadrícula
plt.legend()
plt.grid(True)

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ## Ejercicio 06
#
# Seleccione las columnas que considere pertinentes del dataset y haga un histograma. Coloque título al gráfico y etiquete los dos ejes.

# %%
# Escriba su código aquí

# Agrupar los datos por generación y contar el número de Pokémones
cantidad_por_generacion = df_pokemon['generation'].value_counts()

# Obtener los índices de las generaciones
generaciones = cantidad_por_generacion.index

# Obtener la cantidad de Pokémon por generación
cantidad_pokemon = cantidad_por_generacion.values

# Crear el histograma
plt.figure(figsize=(10, 6))
plt.bar(generaciones, cantidad_pokemon, color='olive')

# Título y etiquetas de los ejes
plt.title('Cantidad de Pokémones por Generación')
plt.xlabel('Generación')
plt.ylabel('Cantidad')

# Establecer las etiquetas del eje x como las generaciones
plt.xticks(generaciones)

# Mostrar la cuadrícula
plt.grid(True)

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ## Ejercicio 07
#
# Seleccione las columnas que considere pertinentes del dataset y haga un gráfico de torta (**pie chart**). Coloque título al gráfico y etiquete los segmentos del gráfico.

# %%
# Escriba su código aquí

# Seleccionar las columnas pertinentes del DataFrame
columna_pertinente = 'type1'

# Contar la cantidad de Pokemónes por su tipo
conteo_valores = df_pokemon[columna_pertinente].value_counts()

# Obtener los valores y las etiquetas para el gráfico de torta
valores = conteo_valores.values
etiquetas = conteo_valores.index

# Colores personalizados (usando una paleta de colores predefinida)
colores = plt.cm.tab20c.colors[:len(etiquetas)]

# Creamos una lista explode que tenga un valor de 0 para todos los
# segmentos excepto los últimos cinco.
# Esto resalta los últimos 5, los más raros
explode = np.zeros(len(etiquetas))
explode[-5:] = 0.1

# Crear el gráfico de torta, con los colores y los resaltos
plt.figure(figsize=(8, 8))
plt.pie(valores,
        labels=etiquetas,
        colors=colores,
        explode=explode,
        autopct='%1.1f%%',
        shadow=False
        )

# Título del gráfico
plt.title('Distribución de Pokémon por Tipo')

# Normalizar el ancho y alto de la figura
plt.axis('equal')

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ## Ejercicio 08
#
# Seleccione las columnas que considere pertinentes del dataset y haga un mapa de calor (**heatmap**). Coloque título al gráfico y etiquete los dos ejes.

# %%
# Escriba su código aquí

# Seleccionar las columnas pertinentes del DataFrame
columnas_pertinentes = ['generation',
                        'hp',
                        'attack',
                        'defense',
                        'speed',
                        'sp_attack',
                        'sp_defense']

# Filtrar el DataFrame para incluir solo las columnas pertinentes
datos_seleccionados = df_pokemon[columnas_pertinentes]

# Agrupar los datos por generación y calcular el promedio de cada columna
promedios_generacion = datos_seleccionados.groupby('generation').mean()

# Crear un mapa de calor (heatmap) de los promedios por generación
plt.figure(figsize=(10, 6))
heatmap = plt.imshow(promedios_generacion.T,
                     cmap='viridis',
                     aspect='auto',
                     interpolation='nearest')

# Añadir título y etiquetas de los ejes
plt.title('Promedio de Atributos por Generación')
plt.xlabel('Generación')
plt.ylabel('Atributo')

# Añadir barra de color
plt.colorbar(heatmap, label='Valor Promedio')

# Ajustar la ubicación de las etiquetas del eje x
plt.xticks(np.arange(len(promedios_generacion.index)),
           promedios_generacion.index)

# Obtener los nombres de los atributos
nombres_atributos = ['HP',
                     'Ataque',
                     'Defensa',
                     'Velocidad',
                     'Super Ataque',
                     'Super Defensa']

# Añadir nombres de los atributos a la barra de color
plt.yticks(np.arange(len(nombres_atributos)), nombres_atributos)

# Mostrar el mapa de calor
plt.show()

# %% [markdown]
# ## Ejercicio 09
#
# Seleccione las columnas que considere pertinentes del dataset y haga un gráfico en 3D. Coloque título al gráfico y etiquete los ejes.

# %%
# Escriba su código aquí

# Importar la librería necesaria para graficar en 3D
from mpl_toolkits.mplot3d import Axes3D

# Seleccionar las columnas pertinentes del DataFrame
columnas_pertinentes = ['hp', 'attack', 'defense']

# Obtener los datos para las columnas seleccionadas
datos_seleccionados = df_pokemon[columnas_pertinentes]

# Crear una figura y un espacio tridimensional
fig = plt.figure(figsize=(12, 18))
ax = fig.add_subplot(111, projection='3d')

# Obtener valores para cada eje
x = datos_seleccionados['attack']
y = datos_seleccionados['hp']
z = datos_seleccionados['defense']

# Graficar los puntos en 3D
ax.scatter(x, y, z, c='r', marker='o')

# Etiquetar los ejes
ax.set_xlabel('Ataque')
ax.set_ylabel('Puntos de vida (HP)')
ax.set_zlabel('Defensa')

# Título del gráfico
plt.title('Gráfico en 3D de HP, Ataque y Defensa de los Pokemón')

# Mostrar el gráfico
plt.show()
